# %% [markdown]
# <center>
# <h1> Linear Regression Case Study
# </center>
#
# #### Steps for Regression Modeling:
# 1. Business problem definition - One of major automobile company would like to design new product which can improve the sales. Inorder to define the product, they want to understand identify drivers for the sales(what are the factors driving sales) and Predicting sales of different car models given driving factors.
# 2. convert business problem into statistical problem  sales = F(sales attributes, product features, marketing info etc.)
# 3. Finding the right technique - Since it is predicting value (Regression Problem) problem so we can use OLS as one of the technique. We can also use other techniques like Decision Trees, Ensemble learning, KNN, SVM, ANN etc.
# 4. Data colletion(Y, X) - Identify the sources of information and collect the data
# 5. Consolidate the data - aggregate and consolidate the data at Model level/customer level/store level depends on business problem
# 6. Data preparation for modeling (create data audit report to identify the steps to perform as part of data preparation)
#     a. missing value treatment
#     b. outlier treatment
#     c. dummy variable creation
# 7. Variable creation by using transformation and derived variable creation.
# 8. Basic assumptions (Normality, linearity, no outliers, homoscadasticity, no pattern in residuals, no auto correlation etc)
# 9. Variable reduction techniques (removing multicollinerity with the help of FA/PCA, correlation matrics, VIF)
# 10. Create dev and validation data sets (50:50 if you have more data else 70:30 or 80:20)
# 11. Modeling on dev data set (identify significant variables, model interpretation, check the signs and coefficients, multi-collinierity check, measures of good neess fit, final mathematical equation etc)
# 12. validating on validation data set (check the stability of model, scoring, decile analysis, cross validation etc.)
# 13. Output interpretation and derive insights (understand the limitations of the model and define strategy to implementation)
# 14. convert statistical solution into business solutions (implementation, model monitoring etc)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stat
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling 
import statsmodels.api as smf
# %pylab inline
#%matplotlib inline

plt.rcParams['figure.figsize'] = 10, 7.5
plt.rcParams['axes.grid'] = True
plt.gray()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#from sklearn.preprocessing import imputation
#from sklearn.preprocessing import StandardScaler
#from sklearn.linear_model import  Lasso, Ridge, ElasticNet
#from sklearn.decomposition import PCA
#from sklearn.manifold import TSNE
#from sklearn.cluster import KMeans, DBSCAN
#from sklearn.svm import SVR
#from sklearn.neighbors import KNeighborsRegressor
#from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor

# %%
# %pwd
# Out:
# 'F:\\Tech M HYD\\Week2 Material for Tech Mahindra\\2. Linear Regression\\1. Case Study - Automobile Example - Class Exercise'

# %%
car_sales = pd.read_csv('Car_sales.csv')

# %%
car_sales.info()

# %%
car_sales.head()

# %%
car_sales.describe()

# %%
car_sales.columns

# %%
#Detailed profiling using pandas profiling

output = pandas_profiling.ProfileReport(car_sales)

# %%
car_sales.dtypes
# Out:
# Manufacturer               object
# Model                      object
# Sales_in_thousands        float64
# four_year_resale_value    float64
# Vehicle_type               object
# Price_in_thousands        float64
# Engine_size               float64
# Horsepower                float64
# Wheelbase                 float64
# Width                     float64
# Length                    float64
# Curb_weight               float64
# Fuel_capacity             float64
# Fuel_efficiency           float64
# Latest_Launch              object
# Power_perf_factor         float64
# dtype: object

# %%
dict(car_sales.dtypes)
# Out:
# {'Manufacturer': dtype('O'),
#  'Model': dtype('O'),
#  'Sales_in_thousands': dtype('float64'),
#  'four_year_resale_value': dtype('float64'),
#  'Vehicle_type': dtype('O'),
#  'Price_in_thousands': dtype('float64'),
#  'Engine_size': dtype('float64'),
#  'Horsepower': dtype('float64'),
#  'Wheelbase': dtype('float64'),
#  'Width': dtype('float64'),
#  'Length': dtype('float64'),
#  'Curb_weight': dtype('float64'),
#  'Fuel_capacity': dtype('float64'),
#  'Fuel_efficiency': dtype('float64'),
#  'Latest_Launch': dtype('O'),
#  'Power_perf_factor': dtype('float64')}

# %%
numeric_var_names=[key for key in dict(car_sales.dtypes) if dict(car_sales.dtypes)[key] in ['float64', 'int64', 'float32', 'int32']]
cat_var_names=[key for key in dict(car_sales.dtypes) if dict(car_sales.dtypes)[key] in ['object', 'O']]

# %%
print(numeric_var_names)
print(cat_var_names)
# Out:
# ['Sales_in_thousands', 'four_year_resale_value', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor']
# ['Manufacturer', 'Model', 'Vehicle_type', 'Latest_Launch']

# %%
car_sales_num=car_sales[numeric_var_names]
car_sales_num.head(5)
# Out:
#    Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 0              16.919                  16.360               21.50
# 1              39.384                  19.875               28.40
# 2              14.114                  18.225                 NaN
# 3               8.588                  29.725               42.00
# 4              20.397                  22.255               23.99
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  Fuel_efficiency  Power_perf_factor
# 0           13.2             28.0          58.280150
# 1           17.2             25.0          91.370778
# 2           17.2             26.0                NaN
# 3           18.0             22.0          91.389779
# 4           16.4             27.0          62.777639

# %%
car_sales_cat = car_sales[cat_var_names]
car_sales_cat.head(5)
# Out:
#   Manufacturer    Model Vehicle_type Latest_Launch
# 0        Acura  Integra    Passenger      2/2/2012
# 1        Acura       TL    Passenger      6/3/2011
# 2        Acura       CL    Passenger      1/4/2012
# 3        Acura       RL    Passenger     3/10/2011
# 4         Audi       A4    Passenger     10/8/2011

# %%
car_sales_num.Sales_in_thousands.mean()

# %%
#user defined function in python

# %%
def test_summary(x):
    mean = x.mean()
    sum = x.sum()
    std = x.std()
    return pd.Series([mean, sum, std], index=['avg', 'total', 'std'])

# %%
test_summary(car_sales_num.Sales_in_thousands)

# %%
car_sales_num.apply(test_summary).T

# %%
# Creating Data audit Report
# Use a general function that returns multiple values
def var_summary(x):
    return pd.Series([x.count(), x.isnull().sum(), x.sum(), x.mean(), x.median(),  x.std(), x.var(), x.std()/x.mean(), x.min(), x.dropna().quantile(0.01), x.dropna().quantile(0.05),x.dropna().quantile(0.10),x.dropna().quantile(0.25),x.dropna().quantile(0.50),x.dropna().quantile(0.75), x.dropna().quantile(0.90),x.dropna().quantile(0.95), x.dropna().quantile(0.99),x.max()], 
                  index=['N', 'NMISS', 'SUM', 'MEAN','MEDIAN', 'STD', 'VAR', 'CV','MIN', 'P1' , 'P5' ,'P10' ,'P25' ,'P50' ,'P75' ,'P90' ,'P95' ,'P99' ,'MAX'])

# %%
car_sales_num.apply(var_summary)
# Out:
#         Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# N               157.000000              121.000000          155.000000
# NMISS             0.000000               36.000000            2.000000
# SUM            8320.698000             2186.830000         4245.567000
# MEAN             52.998076               18.072975           27.390755
# MEDIAN           29.450000               14.180000           22.799000
# STD              68.029422               11.453384           14.351653
# VAR            4628.002257              131.180007          205.969949
# CV                1.283621                0.633730            0.523960
# MIN               0.110000                5.160000            9.235000
# P1                0.937280                6.173000           10.231440
# P5                1.870800                7.850000           12.469000
# P10               5.453600                9.125000           13.970800
# P25              14.114000               11.260000           18.017500
# P50              29.450000               14.180000           22.799000
# P75              67.956000               19.875000           31.947500
# P90             127.641600               32.075000           44.017000
# P95             185.336200               41.250000           55.835000
# P99             260.645320               60.220000           78.479800
# MAX             540.561000               67.550000           85.500000
#
#         Engine_size    Horsepower     Wheelbase         Width        Length  \
# N        156.000000    156.000000    156.000000    156.000000    156.000000
# NMISS      1.000000      1.000000      1.000000      1.000000      1.000000
# SUM      477.500000  29008.000000  16768.000000  11099.400000  29225.600000
# MEAN       3.060897    185.948718    107.487179     71.150000    187.343590
# MEDIAN     3.000000    177.500000    107.000000     70.550000    187.900000
# STD        1.044653     56.700321      7.641303      3.451872     13.431754
# VAR        1.091300   3214.926385     58.389512     11.915419    180.412023
# CV         0.341290      0.304925      0.071090      0.048515      0.071696
# MIN        1.000000     55.000000     92.600000     62.600000    149.400000
# P1         1.555000     96.400000     92.875000     66.085000    154.915000
# P5         1.800000    114.500000     95.875000     66.500000    163.675000
# P10        1.950000    120.000000     98.650000     66.900000    173.000000
# P25        2.300000    149.500000    103.000000     68.400000    177.575000
# P50        3.000000    177.500000    107.000000     70.550000    187.900000
# P75        3.575000    215.000000    112.200000     73.425000    196.125000
# P90        4.600000    254.000000    115.500000     76.200000    203.400000
# P95        4.775000    300.000000    119.250000     78.200000    208.500000
# P99        5.700000    325.750000    134.375000     79.190000    219.305000
# MAX        8.000000    450.000000    138.700000     79.900000    224.500000
#
#         Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor
# N        155.000000     156.000000       154.000000         155.000000
# NMISS      2.000000       1.000000         3.000000           2.000000
# SUM      523.594000    2800.500000      3672.000000       11941.756636
# MEAN       3.378026      17.951923        23.844156          77.043591
# MEDIAN     3.342000      17.200000        24.000000          72.030917
# STD        0.630502       3.887921         4.282706          25.142664
# VAR        0.397532      15.115932        18.341567         632.153558
# CV         0.186648       0.216574         0.179612           0.326343
# MIN        1.895000      10.300000        15.000000          23.276272
# P1         2.245400      11.900000        15.000000          38.461920
# P5         2.423500      12.500000        16.650000          46.203997
# P10        2.606200      13.200000        18.300000          48.447741
# P25        2.971000      15.800000        21.000000          60.407707
# P50        3.342000      17.200000        24.000000          72.030917
# P75        3.799500      19.575000        26.000000          89.414878
# P90        4.118600      23.200000        28.700000         108.499252
# P95        4.389100      25.400000        31.000000         125.091513
# P99        5.396680      30.900000        33.000000         141.119461
# MAX        5.572000      32.000000        45.000000         188.144323

# %%
num_summary=car_sales_num.apply(var_summary).T

# %%
num_summary.to_csv('num_summary.csv')

# %%
num_summary
# Out:
#                             N  NMISS           SUM        MEAN      MEDIAN  \
# Sales_in_thousands      157.0    0.0   8320.698000   52.998076   29.450000
# four_year_resale_value  121.0   36.0   2186.830000   18.072975   14.180000
# Price_in_thousands      155.0    2.0   4245.567000   27.390755   22.799000
# Engine_size             156.0    1.0    477.500000    3.060897    3.000000
# Horsepower              156.0    1.0  29008.000000  185.948718  177.500000
# Wheelbase               156.0    1.0  16768.000000  107.487179  107.000000
# Width                   156.0    1.0  11099.400000   71.150000   70.550000
# Length                  156.0    1.0  29225.600000  187.343590  187.900000
# Curb_weight             155.0    2.0    523.594000    3.378026    3.342000
# Fuel_capacity           156.0    1.0   2800.500000   17.951923   17.200000
# Fuel_efficiency         154.0    3.0   3672.000000   23.844156   24.000000
# Power_perf_factor       155.0    2.0  11941.756636   77.043591   72.030917
#
#                               STD          VAR        CV         MIN  \
# Sales_in_thousands      68.029422  4628.002257  1.283621    0.110000
# four_year_resale_value  11.453384   131.180007  0.633730    5.160000
# Price_in_thousands      14.351653   205.969949  0.523960    9.235000
# Engine_size              1.044653     1.091300  0.341290    1.000000
# Horsepower              56.700321  3214.926385  0.304925   55.000000
# Wheelbase                7.641303    58.389512  0.071090   92.600000
# Width                    3.451872    11.915419  0.048515   62.600000
# Length                  13.431754   180.412023  0.071696  149.400000
# Curb_weight              0.630502     0.397532  0.186648    1.895000
# Fuel_capacity            3.887921    15.115932  0.216574   10.300000
# Fuel_efficiency          4.282706    18.341567  0.179612   15.000000
# Power_perf_factor       25.142664   632.153558  0.326343   23.276272
#
#                                P1          P5         P10         P25  \
# Sales_in_thousands        0.93728    1.870800    5.453600   14.114000
# four_year_resale_value    6.17300    7.850000    9.125000   11.260000
# Price_in_thousands       10.23144   12.469000   13.970800   18.017500
# Engine_size               1.55500    1.800000    1.950000    2.300000
# Horsepower               96.40000  114.500000  120.000000  149.500000
# Wheelbase                92.87500   95.875000   98.650000  103.000000
# Width                    66.08500   66.500000   66.900000   68.400000
# Length                  154.91500  163.675000  173.000000  177.575000
# Curb_weight               2.24540    2.423500    2.606200    2.971000
# Fuel_capacity            11.90000   12.500000   13.200000   15.800000
# Fuel_efficiency          15.00000   16.650000   18.300000   21.000000
# Power_perf_factor        38.46192   46.203997   48.447741   60.407707
#
#                                P50         P75         P90         P95  \
# Sales_in_thousands       29.450000   67.956000  127.641600  185.336200
# four_year_resale_value   14.180000   19.875000   32.075000   41.250000
# Price_in_thousands       22.799000   31.947500   44.017000   55.835000
# Engine_size               3.000000    3.575000    4.600000    4.775000
# Horsepower              177.500000  215.000000  254.000000  300.000000
# Wheelbase               107.000000  112.200000  115.500000  119.250000
# Width                    70.550000   73.425000   76.200000   78.200000
# Length                  187.900000  196.125000  203.400000  208.500000
# Curb_weight               3.342000    3.799500    4.118600    4.389100
# Fuel_capacity            17.200000   19.575000   23.200000   25.400000
# Fuel_efficiency          24.000000   26.000000   28.700000   31.000000
# Power_perf_factor        72.030917   89.414878  108.499252  125.091513
#
#                                P99         MAX
# Sales_in_thousands      260.645320  540.561000
# four_year_resale_value   60.220000   67.550000
# Price_in_thousands       78.479800   85.500000
# Engine_size               5.700000    8.000000
# Horsepower              325.750000  450.000000
# Wheelbase               134.375000  138.700000
# Width                    79.190000   79.900000
# Length                  219.305000  224.500000
# Curb_weight               5.396680    5.572000
# Fuel_capacity            30.900000   32.000000
# Fuel_efficiency          33.000000   45.000000
# Power_perf_factor       141.119461  188.144323

# %%
car_sales_cat=car_sales.select_dtypes(include=['object'])

# %%
car_sales_cat.head(5)
# Out:
#   Manufacturer    Model Vehicle_type Latest_Launch
# 0        Acura  Integra    Passenger    2012-02-02
# 1        Acura       TL    Passenger    2011-06-03
# 2        Acura       CL    Passenger    2012-01-04
# 3        Acura       RL    Passenger    2011-03-10
# 4         Audi       A4    Passenger    2011-10-08

# %%
car_sales_cat.Latest_Launch = pd.to_datetime(car_sales_cat.Latest_Launch)
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
car_sales_cat["Launch_Year"] = car_sales_cat.Latest_Launch.dt.year
LD = car_sales_cat.Latest_Launch
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
del car_sales_cat["Latest_Launch"]

# %%
def cat_summary(x):
    return pd.Series([x.count(), x.isnull().sum(), x.value_counts()], 
                  index=['N', 'NMISS', 'ColumnsNames'])

cat_summary=car_sales_cat.apply(cat_summary)

# %%
cat_summary
# Out:
#                                                    Manufacturer  \
# N                                                           157
# NMISS                                                         0
# ColumnsNames  Ford          11
# Dodge         11
# Chevrolet   ...
#
#                                                           Model  \
# N                                                           157
# NMISS                                                         0
# ColumnsNames  Neon              2
# Aurora            1
# Crown ...
#
#                                                    Vehicle_type  \
# N                                                           157
# NMISS                                                         0
# ColumnsNames  Passenger    116
# Car           41
# Name: Vehicl...
#
#                                                     Launch_Year
# N                                                           157
# NMISS                                                         0
# ColumnsNames  2011    79
# 2012    75
# 2009     2
# 2008     1
# Na...

# %% [markdown]
# #### Outlier Treatment

# %%
car_sales['Sales_in_thousands'].quantile(0.99)

# %%
car_sales['Sales_in_thousands'].quantile(0.01)

# %%
#Handling Outliers - Method1
car_sales['Sales_in_thousands']= car_sales['Sales_in_thousands'].clip_upper(car_sales['Sales_in_thousands'].quantile(0.99)) 
car_sales['Sales_in_thousands']= car_sales['Sales_in_thousands'].clip_lower(car_sales['Sales_in_thousands'].quantile(0.01))

# %%
#Handling Outliers - Method2
def outlier_capping(x):
    x = x.clip(lower = x.quantile(0.05),upper = x.quantile(0.95))
    return x

car_sales_num=car_sales_num.apply(outlier_capping)

# %%
car_sales_num.apply(var_summary).T
# Out:
#                             N  NMISS           SUM        MEAN      MEDIAN  \
# Sales_in_thousands      157.0    0.0   7619.795000   48.533726   29.450000
# four_year_resale_value  121.0   36.0   2102.590000   17.376777   14.180000
# Price_in_thousands      155.0    2.0   4126.998000   26.625794   22.799000
# Engine_size             156.0    1.0    471.800000    3.024359    3.000000
# Horsepower              156.0    1.0  28932.000000  185.461538  177.500000
# Wheelbase               156.0    1.0  16720.600000  107.183333  107.000000
# Width                   156.0    1.0  11099.000000   71.147436   70.550000
# Length                  156.0    1.0  29217.700000  187.292949  187.900000
# Curb_weight             155.0    2.0    520.180800    3.356005    3.342000
# Fuel_capacity           156.0    1.0   2781.400000   17.829487   17.200000
# Fuel_efficiency         154.0    3.0   3659.200000   23.761039   24.000000
# Power_perf_factor       155.0    2.0  11854.968376   76.483667   72.030917
#
#                               STD          VAR        CV         MIN  \
# Sales_in_thousands      49.600320  2460.191752  1.021976    1.870800
# four_year_resale_value   8.973437    80.522578  0.516404    7.850000
# Price_in_thousands      11.767895   138.483344  0.441973   12.469000
# Engine_size              0.908499     0.825371  0.300394    1.800000
# Horsepower              50.948853  2595.785608  0.274714  114.500000
# Wheelbase                6.306485    39.771753  0.058838   95.875000
# Width                    3.314182    10.983800  0.046582   66.500000
# Length                  12.068163   145.640563  0.064435  163.675000
# Curb_weight              0.541847     0.293598  0.161456    2.423500
# Fuel_capacity            3.396131    11.533706  0.190478   12.500000
# Fuel_efficiency          3.706015    13.734551  0.155970   16.650000
# Power_perf_factor       22.049305   486.171850  0.288288   46.203997
#
#                                 P1          P5         P10         P25  \
# Sales_in_thousands        1.870800    1.871760    5.453600   14.114000
# four_year_resale_value    7.850000    7.850000    9.125000   11.260000
# Price_in_thousands       12.469000   12.515200   13.970800   18.017500
# Engine_size               1.800000    1.800000    1.950000    2.300000
# Horsepower              114.500000  114.875000  120.000000  149.500000
# Wheelbase                95.875000   96.043750   98.650000  103.000000
# Width                    66.500000   66.500000   66.900000   68.400000
# Length                  163.675000  163.768750  173.000000  177.575000
# Curb_weight               2.423500    2.424550    2.606200    2.971000
# Fuel_capacity            12.500000   12.500000   13.200000   15.800000
# Fuel_efficiency          16.650000   16.877500   18.300000   21.000000
# Power_perf_factor        46.203997   46.315542   48.447741   60.407707
#
#                                P50         P75         P90         P95  \
# Sales_in_thousands       29.450000   67.956000  127.641600  182.466440
# four_year_resale_value   14.180000   19.875000   32.075000   41.250000
# Price_in_thousands       22.799000   31.947500   44.017000   54.554000
# Engine_size               3.000000    3.575000    4.600000    4.718750
# Horsepower              177.500000  215.000000  254.000000  300.000000
# Wheelbase               107.000000  112.200000  115.500000  119.062500
# Width                    70.550000   73.425000   76.200000   78.200000
# Length                  187.900000  196.125000  203.400000  208.500000
# Curb_weight               3.342000    3.799500    4.118600    4.387630
# Fuel_capacity            17.200000   19.575000   23.200000   25.400000
# Fuel_efficiency          24.000000   26.000000   28.700000   31.000000
# Power_perf_factor        72.030917   89.414878  108.499252  125.036804
#
#                                P99         MAX
# Sales_in_thousands      185.336200  185.336200
# four_year_resale_value   41.250000   41.250000
# Price_in_thousands       55.835000   55.835000
# Engine_size               4.775000    4.775000
# Horsepower              300.000000  300.000000
# Wheelbase               119.250000  119.250000
# Width                    78.200000   78.200000
# Length                  208.500000  208.500000
# Curb_weight               4.389100    4.389100
# Fuel_capacity            25.400000   25.400000
# Fuel_efficiency          31.000000   31.000000
# Power_perf_factor       125.091513  125.091513

# %% [markdown]
# #### Handling Missings

# %%
# Fill with mean/Median
car_sales['Sales_in_thousands']=car_sales['Sales_in_thousands'].fillna(car_sales['Sales_in_thousands'].median())

# %%
#Handling missings - Method2
def Missing_imputation(x):
    x = x.fillna(x.median())
    return x

car_sales_num=car_sales_num.apply(Missing_imputation)

# %%
num_summary=car_sales_num.apply(var_summary).T
num_summary
# Out:
#                             N  NMISS          SUM        MEAN      MEDIAN  \
# Sales_in_thousands      157.0    0.0   7619.79500   48.533726   29.450000
# four_year_resale_value  157.0    0.0   2613.07000   16.643758   14.180000
# Price_in_thousands      157.0    0.0   4172.59600   26.577045   22.799000
# Engine_size             157.0    0.0    474.80000    3.024204    3.000000
# Horsepower              157.0    0.0  29109.50000  185.410828  177.500000
# Wheelbase               157.0    0.0  16827.60000  107.182166  107.000000
# Width                   157.0    0.0  11169.55000   71.143631   70.550000
# Length                  157.0    0.0  29405.60000  187.296815  187.900000
# Curb_weight             157.0    0.0    526.86480    3.355827    3.342000
# Fuel_capacity           157.0    0.0   2798.60000   17.825478   17.200000
# Fuel_efficiency         157.0    0.0   3731.20000   23.765605   24.000000
# Power_perf_factor       157.0    0.0  11999.03021   76.426944   72.030917
#
#                               STD          VAR        CV         MIN  \
# Sales_in_thousands      49.600320  2460.191752  1.021976    1.870800
# four_year_resale_value   7.984861    63.758003  0.479751    7.850000
# Price_in_thousands      11.700140   136.893273  0.440235   12.469000
# Engine_size              0.905585     0.820083  0.299446    1.800000
# Horsepower              50.789267  2579.549690  0.273928  114.500000
# Wheelbase                6.286256    39.517020  0.058650   95.875000
# Width                    3.303886    10.915664  0.046440   66.500000
# Length                  12.029519   144.709317  0.064227  163.675000
# Curb_weight              0.538365     0.289837  0.160427    2.423500
# Fuel_capacity            3.385601    11.462295  0.189930   12.500000
# Fuel_efficiency          3.670354    13.471502  0.154440   16.650000
# Power_perf_factor       21.913234   480.189832  0.286721   46.203997
#
#                                 P1          P5         P10         P25  \
# Sales_in_thousands        1.870800    1.871760    5.453600   14.114000
# four_year_resale_value    7.850000    8.425000    9.710000   12.545000
# Price_in_thousands       12.469000   12.521800   13.976200   18.145000
# Engine_size               1.800000    1.800000    1.960000    2.300000
# Horsepower              114.500000  114.900000  120.000000  150.000000
# Wheelbase                95.875000   96.055000   98.700000  103.000000
# Width                    66.500000   66.500000   66.900000   68.400000
# Length                  163.675000  163.775000  173.120000  177.600000
# Curb_weight               2.423500    2.424700    2.612800    2.975000
# Fuel_capacity            12.500000   12.500000   13.200000   15.800000
# Fuel_efficiency          16.650000   16.930000   18.600000   21.000000
# Power_perf_factor        46.203997   46.331477   48.522793   60.727447
#
#                                P50         P75        P90         P95  \
# Sales_in_thousands       29.450000   67.956000  127.64160  182.466440
# four_year_resale_value   14.180000   18.140000   27.02500   39.275000
# Price_in_thousands       22.799000   31.930000   43.78800   54.371000
# Engine_size               3.000000    3.500000    4.60000    4.715000
# Horsepower              177.500000  215.000000  253.80000  300.000000
# Wheelbase               107.000000  112.200000  115.46000  119.050000
# Width                    70.550000   73.400000   76.18000   78.200000
# Length                  187.900000  196.100000  203.34000  208.500000
# Curb_weight               3.342000    3.778000    4.11740    4.387420
# Fuel_capacity            17.200000   19.500000   23.20000   25.400000
# Fuel_efficiency          24.000000   26.000000   28.40000   31.000000
# Power_perf_factor        72.030917   89.401935  107.99432  125.028988
#
#                                P99         MAX
# Sales_in_thousands      185.336200  185.336200
# four_year_resale_value   41.250000   41.250000
# Price_in_thousands       55.835000   55.835000
# Engine_size               4.775000    4.775000
# Horsepower              300.000000  300.000000
# Wheelbase               119.250000  119.250000
# Width                    78.200000   78.200000
# Length                  208.500000  208.500000
# Curb_weight               4.389100    4.389100
# Fuel_capacity            25.400000   25.400000
# Fuel_efficiency          31.000000   31.000000
# Power_perf_factor       125.091513  125.091513

# %%
#Handling missings - Method2
def Missing_imputation_cat(x):
    x = x.fillna(x.mode())
    return x

car_sales_cat1 = car_sales_cat.apply(Missing_imputation_cat)

# %%
def cat_summary(x):
    return pd.Series([x.count(), x.isnull().sum(), x.value_counts()], 
                  index=['N', 'NMISS', 'ColumnsNames'])

cat_summary_table=car_sales_cat1.apply(cat_summary)
cat_summary_table
# Out:
#                                                    Manufacturer  \
# N                                                           157
# NMISS                                                         0
# ColumnsNames  Ford          11
# Dodge         11
# Chevrolet   ...
#
#                                                           Model  \
# N                                                           157
# NMISS                                                         0
# ColumnsNames  Neon              2
# Aurora            1
# Crown ...
#
#                                                    Vehicle_type  \
# N                                                           157
# NMISS                                                         0
# ColumnsNames  Passenger    116
# Car           41
# Name: Vehicl...
#
#                                                     Launch_Year
# N                                                           157
# NMISS                                                         0
# ColumnsNames  2011    79
# 2012    75
# 2009     2
# 2008     1
# Na...

# %% [markdown]
# ## Handling categorical features
#
# scikit-learn expects all features to be numeric. So how do we include a categorical feature in our model?
#
# - **Ordered categories:** transform them to sensible numeric values (example: small=1, medium=2, large=3)
# - **Unordered categories:** use dummy encoding (0/1)
#
# What are the categorical features in our dataset?
#
# - **Ordered categories:** weather (already encoded with sensible numeric values)
# - **Unordered categories:** season (needs dummy encoding), holiday (already dummy encoded), workingday (already dummy encoded)
#
# For season, we can't simply leave the encoding as 1 = spring, 2 = summer, 3 = fall, and 4 = winter, because that would imply an **ordered relationship**. Instead, we create **multiple dummy variables:**

# %%
car_sales_cat.Launch_Year.value_counts()
# Out:
# 2011    79
# 2012    75
# 2009     2
# 2008     1
# Name: Launch_Year, dtype: int64

# %%
pd.get_dummies(car_sales_cat.Manufacturer, drop_first=True)

# %%
col_dummies=pd.get_dummies(car_sales['Manufacturer'], prefix='d', drop_first=True)
col_dummies.head(5)

# %%
col_dummies=pd.get_dummies(car_sales['Vehicle_type'], prefix='Vehicle_type', drop_first=True)
car_sales_cat = pd.concat([car_sales_cat, col_dummies], axis=1)
car_sales_cat.drop( 'Vehicle_type', axis = 1, inplace = True )

# %%
car_sales_cat.head(5)

# %%
# An utility function to create dummy variable
def create_dummies( df, colname ):
    col_dummies = pd.get_dummies(df[colname], prefix=colname, drop_first=True)
    df = pd.concat([df, col_dummies], axis=1)
    df.drop( colname, axis = 1, inplace = True )
    return df

# %%
#for c_feature in categorical_features
car_sales_cat=car_sales_cat1[['Manufacturer', 'Vehicle_type','Launch_Year']]

for c_feature in ['Manufacturer', 'Vehicle_type']:
    car_sales_cat[c_feature] = car_sales_cat[c_feature].astype('category')
    car_sales_cat = create_dummies(car_sales_cat , c_feature )
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
car_sales_cat

# %% [markdown]
# #### Final file for analysis

# %%
car_sales_new = pd.concat([car_sales_num, car_sales_cat], axis=1)
car_sales_new.head()
# Out:
#    Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 0              16.919                  16.360              21.500
# 1              39.384                  19.875              28.400
# 2              14.114                  18.225              22.799
# 3               8.588                  29.725              42.000
# 4              20.397                  22.255              23.990
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  ...  Manufacturer_Plymouth  Manufacturer_Pontiac  \
# 0           13.2  ...                      0                     0
# 1           17.2  ...                      0                     0
# 2           17.2  ...                      0                     0
# 3           18.0  ...                      0                     0
# 4           16.4  ...                      0                     0
#
#    Manufacturer_Porsche  Manufacturer_Saab  Manufacturer_Saturn  \
# 0                     0                  0                    0
# 1                     0                  0                    0
# 2                     0                  0                    0
# 3                     0                  0                    0
# 4                     0                  0                    0
#
#    Manufacturer_Subaru  Manufacturer_Toyota  Manufacturer_Volkswagen  \
# 0                    0                    0                        0
# 1                    0                    0                        0
# 2                    0                    0                        0
# 3                    0                    0                        0
# 4                    0                    0                        0
#
#    Manufacturer_Volvo  Vehicle_type_Passenger
# 0                   0                       1
# 1                   0                       1
# 2                   0                       1
# 3                   0                       1
# 4                   0                       1
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Assumptions checks

# %%
#Normality
car_sales_new.Sales_in_thousands.hist()

# Distribution of variables
import seaborn as sns
sns.distplot(car_sales_new.Sales_in_thousands)
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
car_sales_new["ln_sales_in_thousands"]= np.log(car_sales_new["Sales_in_thousands"])

# Distribution of variables
import seaborn as sns
sns.distplot(car_sales_new.ln_sales_in_thousands)
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Linearity
# correlation matrix (ranges from 1 to -1)
corrm=car_sales_new.corr()

# %%
corrm
# Out:
#                          Sales_in_thousands  four_year_resale_value  \
# Sales_in_thousands                 1.000000               -0.316993
# four_year_resale_value            -0.316993                1.000000
# Price_in_thousands                -0.413203                0.765865
# Engine_size                       -0.027315                0.444627
# Horsepower                        -0.289524                0.649256
# Wheelbase                          0.196427                0.058402
# Width                              0.071657                0.196412
# Length                             0.152783                0.088402
# Curb_weight                       -0.043383                0.354896
# Fuel_capacity                      0.035655                0.355462
# Fuel_efficiency                    0.049104               -0.362272
# Power_perf_factor                 -0.314314                0.682164
# Launch_Year                        0.066182               -0.005541
# Manufacturer_Audi                 -0.098383                0.203873
# Manufacturer_BMW                  -0.093248                0.169796
# Manufacturer_Buick                 0.039149               -0.034585
# Manufacturer_Cadillac             -0.095736                0.111820
# Manufacturer_Chevrolet             0.065150               -0.093218
# Manufacturer_Chrysler             -0.086146               -0.048684
# Manufacturer_Dodge                 0.169330               -0.054915
# Manufacturer_Ford                  0.477612               -0.121880
# Manufacturer_Honda                 0.212829               -0.024764
# Manufacturer_Hyundai              -0.007787               -0.148008
# Manufacturer_Infiniti             -0.040193                0.030642
# Manufacturer_Jaguar               -0.053547               -0.024783
# Manufacturer_Jeep                  0.138844               -0.022628
# Manufacturer_Lexus                -0.123881                0.175737
# Manufacturer_Lincoln              -0.056428                0.037986
# Manufacturer_Mercedes-B           -0.176460                0.244091
# Manufacturer_Mercury              -0.035750               -0.066962
# Manufacturer_Mitsubishi           -0.098046               -0.064639
# Manufacturer_Nissan                0.037388               -0.077880
# Manufacturer_Oldsmobile           -0.074892               -0.021736
# Manufacturer_Plymouth             -0.106394               -0.115386
# Manufacturer_Pontiac               0.053307               -0.069133
# Manufacturer_Porsche              -0.125036                0.431485
# Manufacturer_Saab                 -0.087030               -0.035161
# Manufacturer_Saturn               -0.054158               -0.110647
# Manufacturer_Subaru               -0.019451               -0.035161
# Manufacturer_Toyota                0.133415               -0.008103
# Manufacturer_Volkswagen           -0.055094               -0.058259
# Manufacturer_Volvo                -0.144781               -0.061703
# Vehicle_type_Passenger            -0.232265                0.068279
# ln_sales_in_thousands              0.842743               -0.424238
#
#                          Price_in_thousands  Engine_size  Horsepower  \
# Sales_in_thousands                -0.413203    -0.027315   -0.289524
# four_year_resale_value             0.765865     0.444627    0.649256
# Price_in_thousands                 1.000000     0.633382    0.867710
# Engine_size                        0.633382     1.000000    0.808058
# Horsepower                         0.867710     0.808058    1.000000
# Wheelbase                          0.231587     0.563971    0.384576
# Width                              0.371424     0.707827    0.536013
# Length                             0.207781     0.604991    0.437005
# Curb_weight                        0.566786     0.810574    0.654241
# Fuel_capacity                      0.502186     0.714890    0.555035
# Fuel_efficiency                   -0.534373    -0.758759   -0.603223
# Power_perf_factor                  0.914318     0.796719    0.991443
# Launch_Year                        0.031113     0.094229    0.108844
# Manufacturer_Audi                  0.135805    -0.014050    0.086168
# Manufacturer_BMW                   0.078022    -0.050128   -0.000214
# Manufacturer_Buick                 0.002831     0.107614    0.066555
# Manufacturer_Cadillac              0.212691     0.259346    0.252881
# Manufacturer_Chevrolet            -0.130986     0.004770   -0.061804
# Manufacturer_Chrysler             -0.059948    -0.050236    0.029640
# Manufacturer_Dodge                -0.085342     0.095611    0.002701
# Manufacturer_Ford                 -0.128064     0.092155   -0.077145
# Manufacturer_Honda                -0.097972    -0.093268   -0.083510
# Manufacturer_Hyundai              -0.158743    -0.148052   -0.141273
# Manufacturer_Infiniti              0.019826    -0.002147    0.065771
# Manufacturer_Jaguar                0.111369    -0.002147    0.086330
# Manufacturer_Jeep                 -0.066842     0.073566   -0.047080
# Manufacturer_Lexus                 0.286563     0.130830    0.237904
# Manufacturer_Lincoln               0.180862     0.252665    0.214822
# Manufacturer_Mercedes-B            0.391778     0.095072    0.225847
# Manufacturer_Mercury              -0.099622     0.027779   -0.084958
# Manufacturer_Mitsubishi           -0.081677    -0.053654   -0.085568
# Manufacturer_Nissan               -0.078097    -0.026305   -0.070024
# Manufacturer_Oldsmobile           -0.016309     0.094026    0.018069
# Manufacturer_Plymouth             -0.054548    -0.098373   -0.059598
# Manufacturer_Pontiac              -0.062006     0.090345   -0.001618
# Manufacturer_Porsche               0.292676     0.022027    0.239634
# Manufacturer_Saab                  0.029540    -0.110007   -0.017750
# Manufacturer_Saturn               -0.185823    -0.201764   -0.214985
# Manufacturer_Subaru               -0.050472    -0.065964   -0.045796
# Manufacturer_Toyota               -0.094928    -0.109813   -0.120525
# Manufacturer_Volkswagen           -0.151752    -0.233529   -0.254263
# Manufacturer_Volvo                 0.074456    -0.159921   -0.012773
# Vehicle_type_Passenger             0.021100    -0.279626   -0.009067
# ln_sales_in_thousands             -0.562171    -0.100320   -0.397855
#
#                          Wheelbase     Width    Length  Curb_weight  \
# Sales_in_thousands        0.196427  0.071657  0.152783    -0.043383
# four_year_resale_value    0.058402  0.196412  0.088402     0.354896
# Price_in_thousands        0.231587  0.371424  0.207781     0.566786
# Engine_size               0.563971  0.707827  0.604991     0.810574
# Horsepower                0.384576  0.536013  0.437005     0.654241
# Wheelbase                 1.000000  0.687801  0.837878     0.709606
# Width                     0.687801  1.000000  0.693049     0.704025
# Length                    0.837878  0.693049  1.000000     0.663510
# Curb_weight               0.709606  0.704025  0.663510     1.000000
# Fuel_capacity             0.672428  0.624591  0.578615     0.871851
# Fuel_efficiency          -0.500084 -0.562196 -0.415676    -0.819498
# Power_perf_factor         0.376980  0.523491  0.409446     0.660093
# Launch_Year               0.069188  0.105507  0.089850     0.031957
# Manufacturer_Audi         0.020444  0.068785  0.024480     0.034116
# Manufacturer_BMW          0.033066 -0.079546 -0.084932    -0.019028
# Manufacturer_Buick        0.098514  0.110779  0.163201     0.064530
# Manufacturer_Cadillac     0.141763  0.182637  0.206659     0.171888
# Manufacturer_Chevrolet   -0.115720 -0.032386 -0.010731    -0.145996
# Manufacturer_Chrysler     0.066117  0.052893  0.156276    -0.020460
# Manufacturer_Dodge        0.172215  0.279738  0.142828     0.133223
# Manufacturer_Ford         0.159273  0.131232  0.142620     0.033433
# Manufacturer_Honda        0.010936 -0.037648 -0.047143    -0.004031
# Manufacturer_Hyundai     -0.139186 -0.119101 -0.138863    -0.168705
# Manufacturer_Infiniti     0.014283 -0.022940  0.042754    -0.002063
# Manufacturer_Jaguar       0.093501  0.011095  0.026729     0.043889
# Manufacturer_Jeep        -0.136401 -0.071070 -0.190950     0.004466
# Manufacturer_Lexus        0.051996  0.053851  0.039119     0.170132
# Manufacturer_Lincoln      0.179331  0.234067  0.232442     0.200317
# Manufacturer_Mercedes-B  -0.029469 -0.077313 -0.122982     0.146716
# Manufacturer_Mercury      0.089109  0.082097  0.108107     0.042286
# Manufacturer_Mitsubishi  -0.140238 -0.138736 -0.090019    -0.042508
# Manufacturer_Nissan      -0.000863 -0.073141 -0.020789     0.022095
# Manufacturer_Oldsmobile   0.105810  0.006438  0.107553     0.084383
# Manufacturer_Plymouth     0.070130  0.170922 -0.124011    -0.116324
# Manufacturer_Pontiac      0.058623  0.044772  0.105613     0.017460
# Manufacturer_Porsche     -0.251854 -0.061181 -0.162530    -0.102514
# Manufacturer_Saab        -0.048622 -0.073937 -0.015127    -0.046742
# Manufacturer_Saturn      -0.090947 -0.200660 -0.066200    -0.236248
# Manufacturer_Subaru      -0.103911 -0.111878 -0.064386    -0.018167
# Manufacturer_Toyota      -0.096480 -0.116416 -0.111900    -0.107366
# Manufacturer_Volkswagen  -0.231656 -0.190275 -0.312195    -0.177178
# Manufacturer_Volvo       -0.092746 -0.095449 -0.063671    -0.026432
# Vehicle_type_Passenger   -0.359677 -0.228781 -0.120086    -0.502494
# ln_sales_in_thousands     0.223980  0.035209  0.186218    -0.042764
#
#                          Fuel_capacity  ...  Manufacturer_Pontiac  \
# Sales_in_thousands            0.035655  ...              0.053307
# four_year_resale_value        0.355462  ...             -0.069133
# Price_in_thousands            0.502186  ...             -0.062006
# Engine_size                   0.714890  ...              0.090345
# Horsepower                    0.555035  ...             -0.001618
# Wheelbase                     0.672428  ...              0.058623
# Width                         0.624591  ...              0.044772
# Length                        0.578615  ...              0.105613
# Curb_weight                   0.871851  ...              0.017460
# Fuel_capacity                 1.000000  ...              0.005386
# Fuel_efficiency              -0.823159  ...              0.058174
# Power_perf_factor             0.565393  ...             -0.011370
# Launch_Year                   0.107549  ...              0.126393
# Manufacturer_Audi             0.070632  ...             -0.027822
# Manufacturer_BMW             -0.024489  ...             -0.027822
# Manufacturer_Buick           -0.003616  ...             -0.032231
# Manufacturer_Cadillac         0.110414  ...             -0.036154
# Manufacturer_Chevrolet       -0.153686  ...             -0.049156
# Manufacturer_Chrysler        -0.079359  ...             -0.043062
# Manufacturer_Dodge            0.203481  ...             -0.054715
# Manufacturer_Ford             0.091831  ...             -0.054715
# Manufacturer_Honda           -0.033615  ...             -0.036154
# Manufacturer_Hyundai         -0.127883  ...             -0.027822
# Manufacturer_Infiniti         0.016002  ...             -0.015960
# Manufacturer_Jaguar           0.013630  ...             -0.015960
# Manufacturer_Jeep             0.083039  ...             -0.027822
# Manufacturer_Lexus            0.159943  ...             -0.039735
# Manufacturer_Lincoln          0.150590  ...             -0.027822
# Manufacturer_Mercedes-B       0.080140  ...             -0.049156
# Manufacturer_Mercury          0.000464  ...             -0.039735
# Manufacturer_Mitsubishi       0.029460  ...             -0.043062
# Manufacturer_Nissan           0.023974  ...             -0.043062
# Manufacturer_Oldsmobile       0.022122  ...             -0.039735
# Manufacturer_Plymouth        -0.123394  ...             -0.032231
# Manufacturer_Pontiac          0.005386  ...              1.000000
# Manufacturer_Porsche         -0.034140  ...             -0.027822
# Manufacturer_Saab            -0.004223  ...             -0.022643
# Manufacturer_Saturn          -0.273304  ...             -0.036154
# Manufacturer_Subaru          -0.047980  ...             -0.022643
# Manufacturer_Toyota          -0.004297  ...             -0.049156
# Manufacturer_Volkswagen      -0.184610  ...             -0.039735
# Manufacturer_Volvo            0.000464  ...             -0.039735
# Vehicle_type_Passenger       -0.592747  ...              0.042875
# ln_sales_in_thousands        -0.020115  ...              0.104299
#
#                          Manufacturer_Porsche  Manufacturer_Saab  \
# Sales_in_thousands                  -0.125036          -0.087030
# four_year_resale_value               0.431485          -0.035161
# Price_in_thousands                   0.292676           0.029540
# Engine_size                          0.022027          -0.110007
# Horsepower                           0.239634          -0.017750
# Wheelbase                           -0.251854          -0.048622
# Width                               -0.061181          -0.073937
# Length                              -0.162530          -0.015127
# Curb_weight                         -0.102514          -0.046742
# Fuel_capacity                       -0.034140          -0.004223
# Fuel_efficiency                     -0.067356          -0.023770
# Power_perf_factor                    0.243532          -0.008651
# Launch_Year                          0.051644           0.012036
# Manufacturer_Audi                   -0.019481          -0.015854
# Manufacturer_BMW                    -0.019481          -0.015854
# Manufacturer_Buick                  -0.022568          -0.018367
# Manufacturer_Cadillac               -0.025314          -0.020602
# Manufacturer_Chevrolet              -0.034418          -0.028012
# Manufacturer_Chrysler               -0.030151          -0.024539
# Manufacturer_Dodge                  -0.038311          -0.031179
# Manufacturer_Ford                   -0.038311          -0.031179
# Manufacturer_Honda                  -0.025314          -0.020602
# Manufacturer_Hyundai                -0.019481          -0.015854
# Manufacturer_Infiniti               -0.011175          -0.009095
# Manufacturer_Jaguar                 -0.011175          -0.009095
# Manufacturer_Jeep                   -0.019481          -0.015854
# Manufacturer_Lexus                  -0.027822          -0.022643
# Manufacturer_Lincoln                -0.019481          -0.015854
# Manufacturer_Mercedes-B             -0.034418          -0.028012
# Manufacturer_Mercury                -0.027822          -0.022643
# Manufacturer_Mitsubishi             -0.030151          -0.024539
# Manufacturer_Nissan                 -0.030151          -0.024539
# Manufacturer_Oldsmobile             -0.027822          -0.022643
# Manufacturer_Plymouth               -0.022568          -0.018367
# Manufacturer_Pontiac                -0.027822          -0.022643
# Manufacturer_Porsche                 1.000000          -0.015854
# Manufacturer_Saab                   -0.015854           1.000000
# Manufacturer_Saturn                 -0.025314          -0.020602
# Manufacturer_Subaru                 -0.015854          -0.012903
# Manufacturer_Toyota                 -0.034418          -0.028012
# Manufacturer_Volkswagen             -0.027822          -0.022643
# Manufacturer_Volvo                  -0.027822          -0.022643
# Vehicle_type_Passenger               0.082978           0.067532
# ln_sales_in_thousands               -0.255659          -0.092075
#
#                          Manufacturer_Saturn  Manufacturer_Subaru  \
# Sales_in_thousands                 -0.054158            -0.019451
# four_year_resale_value             -0.110647            -0.035161
# Price_in_thousands                 -0.185823            -0.050472
# Engine_size                        -0.201764            -0.065964
# Horsepower                         -0.214985            -0.045796
# Wheelbase                          -0.090947            -0.103911
# Width                              -0.200660            -0.111878
# Length                             -0.066200            -0.064386
# Curb_weight                        -0.236248            -0.018167
# Fuel_capacity                      -0.273304            -0.047980
# Fuel_efficiency                     0.289227             0.022801
# Power_perf_factor                  -0.213800            -0.047648
# Launch_Year                        -0.009517             0.012036
# Manufacturer_Audi                  -0.025314            -0.015854
# Manufacturer_BMW                   -0.025314            -0.015854
# Manufacturer_Buick                 -0.029326            -0.018367
# Manufacturer_Cadillac              -0.032895            -0.020602
# Manufacturer_Chevrolet             -0.044725            -0.028012
# Manufacturer_Chrysler              -0.039180            -0.024539
# Manufacturer_Dodge                 -0.049783            -0.031179
# Manufacturer_Ford                  -0.049783            -0.031179
# Manufacturer_Honda                 -0.032895            -0.020602
# Manufacturer_Hyundai               -0.025314            -0.015854
# Manufacturer_Infiniti              -0.014521            -0.009095
# Manufacturer_Jaguar                -0.014521            -0.009095
# Manufacturer_Jeep                  -0.025314            -0.015854
# Manufacturer_Lexus                 -0.036154            -0.022643
# Manufacturer_Lincoln               -0.025314            -0.015854
# Manufacturer_Mercedes-B            -0.044725            -0.028012
# Manufacturer_Mercury               -0.036154            -0.022643
# Manufacturer_Mitsubishi            -0.039180            -0.024539
# Manufacturer_Nissan                -0.039180            -0.024539
# Manufacturer_Oldsmobile            -0.036154            -0.022643
# Manufacturer_Plymouth              -0.029326            -0.018367
# Manufacturer_Pontiac               -0.036154            -0.022643
# Manufacturer_Porsche               -0.025314            -0.015854
# Manufacturer_Saab                  -0.020602            -0.012903
# Manufacturer_Saturn                 1.000000            -0.020602
# Manufacturer_Subaru                -0.020602             1.000000
# Manufacturer_Toyota                -0.044725            -0.028012
# Manufacturer_Volkswagen            -0.036154            -0.022643
# Manufacturer_Volvo                 -0.036154            -0.022643
# Vehicle_type_Passenger              0.107827            -0.061767
# ln_sales_in_thousands              -0.039289             0.034639
#
#                          Manufacturer_Toyota  Manufacturer_Volkswagen  \
# Sales_in_thousands                  0.133415                -0.055094
# four_year_resale_value             -0.008103                -0.058259
# Price_in_thousands                 -0.094928                -0.151752
# Engine_size                        -0.109813                -0.233529
# Horsepower                         -0.120525                -0.254263
# Wheelbase                          -0.096480                -0.231656
# Width                              -0.116416                -0.190275
# Length                             -0.111900                -0.312195
# Curb_weight                        -0.107366                -0.177178
# Fuel_capacity                      -0.004297                -0.184610
# Fuel_efficiency                     0.095557                 0.130819
# Power_perf_factor                  -0.117823                -0.240455
# Launch_Year                        -0.082396                -0.084150
# Manufacturer_Audi                  -0.034418                -0.027822
# Manufacturer_BMW                   -0.034418                -0.027822
# Manufacturer_Buick                 -0.039873                -0.032231
# Manufacturer_Cadillac              -0.044725                -0.036154
# Manufacturer_Chevrolet             -0.060811                -0.049156
# Manufacturer_Chrysler              -0.053271                -0.043062
# Manufacturer_Dodge                 -0.067688                -0.054715
# Manufacturer_Ford                  -0.067688                -0.054715
# Manufacturer_Honda                 -0.044725                -0.036154
# Manufacturer_Hyundai               -0.034418                -0.027822
# Manufacturer_Infiniti              -0.019744                -0.015960
# Manufacturer_Jaguar                -0.019744                -0.015960
# Manufacturer_Jeep                  -0.034418                -0.027822
# Manufacturer_Lexus                 -0.049156                -0.039735
# Manufacturer_Lincoln               -0.034418                -0.027822
# Manufacturer_Mercedes-B            -0.060811                -0.049156
# Manufacturer_Mercury               -0.049156                -0.039735
# Manufacturer_Mitsubishi            -0.053271                -0.043062
# Manufacturer_Nissan                -0.053271                -0.043062
# Manufacturer_Oldsmobile            -0.049156                -0.039735
# Manufacturer_Plymouth              -0.039873                -0.032231
# Manufacturer_Pontiac               -0.049156                -0.039735
# Manufacturer_Porsche               -0.034418                -0.027822
# Manufacturer_Saab                  -0.028012                -0.022643
# Manufacturer_Saturn                -0.044725                -0.036154
# Manufacturer_Subaru                -0.028012                -0.022643
# Manufacturer_Toyota                 1.000000                -0.049156
# Manufacturer_Volkswagen            -0.049156                 1.000000
# Manufacturer_Volvo                 -0.049156                -0.039735
# Vehicle_type_Passenger             -0.165280                 0.118509
# ln_sales_in_thousands               0.147327                -0.038370
#
#                          Manufacturer_Volvo  Vehicle_type_Passenger  \
# Sales_in_thousands                -0.144781               -0.232265
# four_year_resale_value            -0.061703                0.068279
# Price_in_thousands                 0.074456                0.021100
# Engine_size                       -0.159921               -0.279626
# Horsepower                        -0.012773               -0.009067
# Wheelbase                         -0.092746               -0.359677
# Width                             -0.095449               -0.228781
# Length                            -0.063671               -0.120086
# Curb_weight                       -0.026432               -0.502494
# Fuel_capacity                      0.000464               -0.592747
# Fuel_efficiency                    0.040013                0.605752
# Power_perf_factor                  0.004897               -0.012275
# Launch_Year                       -0.084150               -0.005560
# Manufacturer_Audi                 -0.027822                0.082978
# Manufacturer_BMW                  -0.027822                0.082978
# Manufacturer_Buick                -0.032231                0.096127
# Manufacturer_Cadillac             -0.036154                0.025247
# Manufacturer_Chevrolet            -0.049156                0.146607
# Manufacturer_Chrysler             -0.043062                0.058174
# Manufacturer_Dodge                -0.054715               -0.177659
# Manufacturer_Ford                 -0.054715               -0.120852
# Manufacturer_Honda                -0.036154               -0.139912
# Manufacturer_Hyundai              -0.027822                0.082978
# Manufacturer_Infiniti             -0.015960                0.047599
# Manufacturer_Jaguar               -0.015960                0.047599
# Manufacturer_Jeep                 -0.027822               -0.234767
# Manufacturer_Lexus                -0.039735               -0.032758
# Manufacturer_Lincoln              -0.027822               -0.022937
# Manufacturer_Mercedes-B           -0.049156                0.084229
# Manufacturer_Mercury              -0.039735               -0.032758
# Manufacturer_Mitsubishi           -0.043062               -0.012082
# Manufacturer_Nissan               -0.043062               -0.152594
# Manufacturer_Oldsmobile           -0.039735               -0.032758
# Manufacturer_Plymouth             -0.032231                0.004103
# Manufacturer_Pontiac              -0.039735                0.042875
# Manufacturer_Porsche              -0.027822                0.082978
# Manufacturer_Saab                 -0.022643                0.067532
# Manufacturer_Saturn               -0.036154                0.107827
# Manufacturer_Subaru               -0.022643               -0.061767
# Manufacturer_Toyota               -0.049156               -0.165280
# Manufacturer_Volkswagen           -0.039735                0.118509
# Manufacturer_Volvo                 1.000000                0.118509
# Vehicle_type_Passenger             0.118509                1.000000
# ln_sales_in_thousands             -0.168885               -0.272024
#
#                          ln_sales_in_thousands
# Sales_in_thousands                    0.842743
# four_year_resale_value               -0.424238
# Price_in_thousands                   -0.562171
# Engine_size                          -0.100320
# Horsepower                           -0.397855
# Wheelbase                             0.223980
# Width                                 0.035209
# Length                                0.186218
# Curb_weight                          -0.042764
# Fuel_capacity                        -0.020115
# Fuel_efficiency                       0.124533
# Power_perf_factor                    -0.427017
# Launch_Year                           0.037697
# Manufacturer_Audi                    -0.132596
# Manufacturer_BMW                     -0.073762
# Manufacturer_Buick                    0.091669
# Manufacturer_Cadillac                -0.081724
# Manufacturer_Chevrolet                0.102332
# Manufacturer_Chrysler                -0.019140
# Manufacturer_Dodge                    0.101469
# Manufacturer_Ford                     0.341301
# Manufacturer_Honda                    0.154982
# Manufacturer_Hyundai                  0.053431
# Manufacturer_Infiniti                -0.010053
# Manufacturer_Jaguar                  -0.038998
# Manufacturer_Jeep                     0.138530
# Manufacturer_Lexus                   -0.139410
# Manufacturer_Lincoln                 -0.011673
# Manufacturer_Mercedes-B              -0.241876
# Manufacturer_Mercury                  0.028207
# Manufacturer_Mitsubishi              -0.096495
# Manufacturer_Nissan                   0.121017
# Manufacturer_Oldsmobile              -0.065947
# Manufacturer_Plymouth                -0.147105
# Manufacturer_Pontiac                  0.104299
# Manufacturer_Porsche                 -0.255659
# Manufacturer_Saab                    -0.092075
# Manufacturer_Saturn                  -0.039289
# Manufacturer_Subaru                   0.034639
# Manufacturer_Toyota                   0.147327
# Manufacturer_Volkswagen              -0.038370
# Manufacturer_Volvo                   -0.168885
# Vehicle_type_Passenger               -0.272024
# ln_sales_in_thousands                 1.000000
#
# [44 rows x 44 columns]

# %%
corrm.to_csv('corrm.csv')

# visualize correlation matrix in Seaborn using a heatmap
sns.heatmap(car_sales_new.corr())

# %%
#Dropping the variables based low correlation with Y

# %%
car_sales_new.drop(['Curb_weight','Fuel_capacity','Manufacturer_BMW','Manufacturer_Buick','Manufacturer_Cadillac','Manufacturer_Chevrolet','Manufacturer_Chrysler','Manufacturer_Hyundai','Manufacturer_Infiniti','Manufacturer_Jaguar','Manufacturer_Lincoln','Manufacturer_Mercury','Manufacturer_Oldsmobile','Manufacturer_Pontiac','Manufacturer_Saab','Manufacturer_Saturn','Manufacturer_Subaru','Manufacturer_Volkswagen'], axis=1, inplace=True)

car_sales_new
# Out:
#      Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 0               16.9190                  16.360              21.500
# 1               39.3840                  19.875              28.400
# 2               14.1140                  18.225              22.799
# 3                8.5880                  29.725              42.000
# 4               20.3970                  22.255              23.990
# 5               18.7800                  23.555              33.950
# 6                1.8708                  39.000              55.835
# 7               19.7470                  14.180              26.990
# 8                9.2310                  28.675              33.400
# 9               17.5270                  36.125              38.900
# 10              91.5610                  12.475              21.975
# 11              39.3500                  13.740              25.300
# 12              27.8510                  20.190              31.965
# 13              83.2570                  13.360              27.885
# 14              63.7290                  22.525              39.895
# 15              15.9430                  27.100              44.475
# 16               6.5360                  25.725              39.665
# 17              11.1850                  18.225              31.010
# 18              14.7850                  14.180              46.225
# 19             145.5190                   9.250              13.260
# 20             135.1260                  11.225              16.535
# 21              24.6290                  10.310              18.890
# 22              42.5930                  11.525              19.390
# 23              26.4020                  13.025              24.340
# 24              17.9470                  36.225              45.705
# 25              32.2990                   9.125              13.960
# 26              21.8550                   7.850              12.469
# 27             107.9950                  14.180              18.890
# 28               7.8540                  12.360              19.840
# 29              32.7750                  14.180              24.495
# ..                  ...                     ...                 ...
# 127              9.1910                  14.180              33.120
# 128             12.1150                  14.180              26.100
# 129             80.6200                   9.200              12.469
# 130             24.5460                  10.590              12.535
# 131              5.2230                  10.790              14.290
# 132              8.4720                  14.180              18.835
# 133             49.9890                  14.180              15.010
# 134             47.1070                  14.180              22.695
# 135             33.0280                  14.180              20.095
# 136            142.5350                  10.025              13.108
# 137            185.3362                  13.245              17.518
# 138             63.8490                  18.140              25.545
# 139             33.2690                  15.445              16.875
# 140             84.0870                   9.575              12.469
# 141             65.1190                  14.180              22.368
# 142             25.1060                  13.325              16.888
# 143             68.4110                  19.425              22.288
# 144              9.8350                  34.080              51.728
# 145              9.7610                  11.425              14.900
# 146             83.7210                  13.240              16.700
# 147             51.1020                  16.725              21.200
# 148              9.5690                  16.575              19.990
# 149              5.5960                  13.760              17.500
# 150             49.4630                  14.180              15.900
# 151             16.9570                  14.180              23.400
# 152              3.5450                  14.180              24.400
# 153             15.2450                  14.180              27.500
# 154             17.5310                  14.180              28.800
# 155              3.4930                  14.180              45.500
# 156             18.9690                  14.180              36.000
#
#      Engine_size  Horsepower  Wheelbase  Width   Length  Fuel_efficiency  \
# 0          1.800       140.0    101.200   67.3  172.400            28.00
# 1          3.200       225.0    108.100   70.3  192.900            25.00
# 2          3.200       225.0    106.900   70.6  192.000            26.00
# 3          3.500       210.0    114.600   71.4  196.600            22.00
# 4          1.800       150.0    102.600   68.2  178.000            27.00
# 5          2.800       200.0    108.700   76.1  192.000            22.00
# 6          4.200       300.0    113.000   74.0  198.200            21.00
# 7          2.500       170.0    107.300   68.4  176.000            26.00
# 8          2.800       193.0    107.300   68.5  176.000            24.00
# 9          2.800       193.0    111.400   70.9  188.000            25.00
# 10         3.100       175.0    109.000   72.7  194.600            25.00
# 11         3.800       240.0    109.000   72.7  196.200            23.00
# 12         3.800       205.0    113.800   74.7  206.800            24.00
# 13         3.800       205.0    112.200   73.5  200.000            25.00
# 14         4.600       275.0    115.300   74.5  207.200            22.00
# 15         4.600       275.0    112.200   75.0  201.000            22.00
# 16         4.600       275.0    108.000   75.5  200.600            22.00
# 17         3.000       200.0    107.400   70.3  194.800            22.00
# 18         4.775       255.0    117.500   77.0  201.200            16.65
# 19         2.200       115.0    104.100   67.9  180.900            27.00
# 20         3.100       170.0    107.000   69.4  190.400            25.00
# 21         3.100       175.0    107.500   72.5  200.900            25.00
# 22         3.400       180.0    110.500   72.7  197.900            27.00
# 23         3.800       200.0    101.100   74.1  193.200            25.00
# 24         4.775       300.0    104.500   73.6  179.700            22.00
# 25         1.800       120.0     97.100   66.7  174.300            31.00
# 26         1.800       114.5     95.875   66.5  163.675            31.00
# 27         3.400       180.0    110.500   73.0  200.000            27.00
# 28         2.500       163.0    103.700   69.7  190.900            24.00
# 29         2.500       168.0    106.000   69.2  193.000            24.00
# ..           ...         ...        ...    ...      ...              ...
# 127        2.300       170.0    106.400   70.6  189.200            23.00
# 128        2.000       185.0    102.600   67.4  182.200            23.00
# 129        1.900       114.5    102.400   66.5  176.900            31.00
# 130        1.900       114.5    102.400   66.5  180.000            31.00
# 131        1.900       124.0    102.400   66.5  176.900            31.00
# 132        2.200       137.0    106.500   69.0  190.400            27.00
# 133        2.200       137.0    106.500   69.0  190.400            28.00
# 134        2.500       165.0    103.500   67.5  185.800            25.00
# 135        2.500       165.0     99.400   68.3  175.200            24.00
# 136        1.800       120.0     97.000   66.7  174.000            31.00
# 137        2.200       133.0    105.200   70.1  188.500            27.00
# 138        3.000       210.0    107.100   71.7  191.900            26.00
# 139        1.800       140.0    102.400   68.3  170.500            31.00
# 140        2.400       142.0    103.300   66.5  178.700            23.00
# 141        3.000       194.0    114.200   73.4  193.500            22.00
# 142        2.000       127.0     95.875   66.7  163.800            27.00
# 143        2.700       150.0    105.300   66.5  183.300            23.00
# 144        4.700       230.0    112.200   76.4  192.500            16.65
# 145        2.000       115.0     98.900   68.3  163.675            26.00
# 146        2.000       115.0     98.900   68.3  172.300            26.00
# 147        1.800       150.0    106.400   68.5  184.100            27.00
# 148        2.000       115.0     97.400   66.7  163.675            26.00
# 149        2.000       115.0     98.900   68.3  163.675            26.00
# 150        2.000       115.0     98.900   67.9  163.675            26.00
# 151        1.900       160.0    100.500   67.6  176.600            25.00
# 152        1.900       160.0    100.500   67.6  176.600            25.00
# 153        2.400       168.0    104.900   69.3  185.900            25.00
# 154        2.400       168.0    104.900   69.3  186.200            25.00
# 155        2.300       236.0    104.900   71.5  185.700            23.00
# 156        2.900       201.0    109.900   72.1  189.800            24.00
#
#      Power_perf_factor  ...  Manufacturer_Lexus  Manufacturer_Mercedes-B  \
# 0            58.280150  ...                   0                        0
# 1            91.370778  ...                   0                        0
# 2            72.030917  ...                   0                        0
# 3            91.389779  ...                   0                        0
# 4            62.777639  ...                   0                        0
# 5            84.565105  ...                   0                        0
# 6           125.091513  ...                   0                        0
# 7            71.191207  ...                   0                        0
# 8            81.877069  ...                   0                        0
# 9            83.998724  ...                   0                        0
# 10           71.181451  ...                   0                        0
# 11           95.636703  ...                   0                        0
# 12           85.828408  ...                   0                        0
# 13           84.254526  ...                   0                        0
# 14          113.854598  ...                   0                        0
# 15          115.621358  ...                   0                        0
# 16          113.765874  ...                   0                        0
# 17           83.483094  ...                   0                        0
# 18          109.509117  ...                   0                        0
# 19           46.363347  ...                   0                        0
# 20           67.314462  ...                   0                        0
# 21           69.991396  ...                   0                        0
# 22           72.030917  ...                   0                        0
# 23           81.118543  ...                   0                        0
# 24          125.091513  ...                   0                        0
# 25           48.297636  ...                   0                        0
# 26           46.203997  ...                   0                        0
# 27           71.838039  ...                   0                        0
# 28           65.957184  ...                   0                        0
# 29           69.521355  ...                   0                        0
# ..                 ...  ...                 ...                      ...
# 127          73.503778  ...                   0                        0
# 128          76.023048  ...                   0                        0
# 129          46.203997  ...                   0                        0
# 130          46.203997  ...                   0                        0
# 131          49.865774  ...                   0                        0
# 132          56.295243  ...                   0                        0
# 133          54.819728  ...                   0                        0
# 134          67.765908  ...                   0                        0
# 135          66.762943  ...                   0                        0
# 136          47.968972  ...                   0                        0
# 137          54.372420  ...                   0                        0
# 138          84.911898  ...                   0                        0
# 139          56.496030  ...                   0                        0
# 140          55.297117  ...                   0                        0
# 141          78.027219  ...                   0                        0
# 142          51.955109  ...                   0                        0
# 143          62.355577  ...                   0                        0
# 144         102.528984  ...                   0                        0
# 145          46.943877  ...                   0                        0
# 146          47.638237  ...                   0                        0
# 147          61.701381  ...                   0                        0
# 148          48.907372  ...                   0                        0
# 149          47.946841  ...                   0                        0
# 150          47.329632  ...                   0                        0
# 151          66.113057  ...                   0                        0
# 152          66.498812  ...                   0                        0
# 153          70.654495  ...                   0                        0
# 154          71.155978  ...                   0                        0
# 155         101.623357  ...                   0                        0
# 156          85.735655  ...                   0                        0
#
#      Manufacturer_Mitsubishi  Manufacturer_Nissan  Manufacturer_Plymouth  \
# 0                          0                    0                      0
# 1                          0                    0                      0
# 2                          0                    0                      0
# 3                          0                    0                      0
# 4                          0                    0                      0
# 5                          0                    0                      0
# 6                          0                    0                      0
# 7                          0                    0                      0
# 8                          0                    0                      0
# 9                          0                    0                      0
# 10                         0                    0                      0
# 11                         0                    0                      0
# 12                         0                    0                      0
# 13                         0                    0                      0
# 14                         0                    0                      0
# 15                         0                    0                      0
# 16                         0                    0                      0
# 17                         0                    0                      0
# 18                         0                    0                      0
# 19                         0                    0                      0
# 20                         0                    0                      0
# 21                         0                    0                      0
# 22                         0                    0                      0
# 23                         0                    0                      0
# 24                         0                    0                      0
# 25                         0                    0                      0
# 26                         0                    0                      0
# 27                         0                    0                      0
# 28                         0                    0                      0
# 29                         0                    0                      0
# ..                       ...                  ...                    ...
# 127                        0                    0                      0
# 128                        0                    0                      0
# 129                        0                    0                      0
# 130                        0                    0                      0
# 131                        0                    0                      0
# 132                        0                    0                      0
# 133                        0                    0                      0
# 134                        0                    0                      0
# 135                        0                    0                      0
# 136                        0                    0                      0
# 137                        0                    0                      0
# 138                        0                    0                      0
# 139                        0                    0                      0
# 140                        0                    0                      0
# 141                        0                    0                      0
# 142                        0                    0                      0
# 143                        0                    0                      0
# 144                        0                    0                      0
# 145                        0                    0                      0
# 146                        0                    0                      0
# 147                        0                    0                      0
# 148                        0                    0                      0
# 149                        0                    0                      0
# 150                        0                    0                      0
# 151                        0                    0                      0
# 152                        0                    0                      0
# 153                        0                    0                      0
# 154                        0                    0                      0
# 155                        0                    0                      0
# 156                        0                    0                      0
#
#      Manufacturer_Porsche  Manufacturer_Toyota  Manufacturer_Volvo  \
# 0                       0                    0                   0
# 1                       0                    0                   0
# 2                       0                    0                   0
# 3                       0                    0                   0
# 4                       0                    0                   0
# 5                       0                    0                   0
# 6                       0                    0                   0
# 7                       0                    0                   0
# 8                       0                    0                   0
# 9                       0                    0                   0
# 10                      0                    0                   0
# 11                      0                    0                   0
# 12                      0                    0                   0
# 13                      0                    0                   0
# 14                      0                    0                   0
# 15                      0                    0                   0
# 16                      0                    0                   0
# 17                      0                    0                   0
# 18                      0                    0                   0
# 19                      0                    0                   0
# 20                      0                    0                   0
# 21                      0                    0                   0
# 22                      0                    0                   0
# 23                      0                    0                   0
# 24                      0                    0                   0
# 25                      0                    0                   0
# 26                      0                    0                   0
# 27                      0                    0                   0
# 28                      0                    0                   0
# 29                      0                    0                   0
# ..                    ...                  ...                 ...
# 127                     0                    0                   0
# 128                     0                    0                   0
# 129                     0                    0                   0
# 130                     0                    0                   0
# 131                     0                    0                   0
# 132                     0                    0                   0
# 133                     0                    0                   0
# 134                     0                    0                   0
# 135                     0                    0                   0
# 136                     0                    1                   0
# 137                     0                    1                   0
# 138                     0                    1                   0
# 139                     0                    1                   0
# 140                     0                    1                   0
# 141                     0                    1                   0
# 142                     0                    1                   0
# 143                     0                    1                   0
# 144                     0                    1                   0
# 145                     0                    0                   0
# 146                     0                    0                   0
# 147                     0                    0                   0
# 148                     0                    0                   0
# 149                     0                    0                   0
# 150                     0                    0                   0
# 151                     0                    0                   1
# 152                     0                    0                   1
# 153                     0                    0                   1
# 154                     0                    0                   1
# 155                     0                    0                   1
# 156                     0                    0                   1
#
#      Vehicle_type_Passenger  ln_sales_in_thousands
# 0                         1               2.828437
# 1                         1               3.673360
# 2                         1               2.647167
# 3                         1               2.150366
# 4                         1               3.015388
# 5                         1               2.932792
# 6                         1               0.626366
# 7                         1               2.983002
# 8                         1               2.222567
# 9                         1               2.863743
# 10                        1               4.517005
# 11                        1               3.672496
# 12                        1               3.326869
# 13                        1               4.421932
# 14                        1               4.154640
# 15                        1               2.769020
# 16                        1               1.877325
# 17                        1               2.414574
# 18                        0               2.693613
# 19                        1               4.980307
# 20                        1               4.906208
# 21                        1               3.203925
# 22                        1               3.751690
# 23                        1               3.273440
# 24                        1               2.887423
# 25                        1               3.475036
# 26                        1               3.084430
# 27                        1               4.682085
# 28                        1               2.061023
# 29                        1               3.489666
# ..                      ...                    ...
# 127                       1               2.218225
# 128                       1               2.494444
# 129                       1               4.389747
# 130                       1               3.200549
# 131                       1               1.653072
# 132                       1               2.136767
# 133                       1               3.911803
# 134                       1               3.852422
# 135                       0               3.497356
# 136                       1               4.959588
# 137                       1               5.222171
# 138                       1               4.156521
# 139                       1               3.504626
# 140                       0               4.431852
# 141                       0               4.176216
# 142                       0               3.223107
# 143                       0               4.225534
# 144                       0               2.285947
# 145                       1               2.278395
# 146                       1               4.427490
# 147                       1               3.933824
# 148                       1               2.258529
# 149                       1               1.722052
# 150                       1               3.901225
# 151                       1               2.830681
# 152                       1               1.265538
# 153                       1               2.724252
# 154                       1               2.863971
# 155                       1               1.250761
# 156                       1               2.942806
#
# [157 rows x 26 columns]

# %%
#Dropping variables with less variance in the data
car_sales_new.drop(['Wheelbase', 'Length', 'Width'], axis=1, inplace=True)

# %%
car_sales_cat2 = car_sales_cat1.copy()

car_sales_cat2["ln_Sales"] = np.log(car_sales_num.Sales_in_thousands)
car_sales_cat2.head()
# Out:
#   Manufacturer    Model Vehicle_type  Launch_Year  ln_Sales
# 0        Acura  Integra    Passenger         2012  2.828437
# 1        Acura       TL    Passenger         2011  3.673360
# 2        Acura       CL    Passenger         2012  2.647167
# 3        Acura       RL    Passenger         2011  2.150366
# 4         Audi       A4    Passenger         2011  3.015388

# %%
import statsmodels.formula.api as smf ## also has a function for Lin Regression
model_1var = smf.ols("ln_Sales ~ Manufacturer",data=car_sales_cat2).fit()
model_1var.fvalue
model_1var.f_pvalue
# Out:
# 4.110448288317048e-08

# %%
model_1var = None
fval = []
pval = []
cols = list(car_sales_cat2.columns.difference(["ln_Sales"]))
for col in cols:
    f = "ln_Sales ~ " + col
    model_1var = smf.ols(formula=f,data=car_sales_cat2).fit()
    fval.append(model_1var.fvalue)
    pval.append(model_1var.f_pvalue)

fval = pd.Series(fval,name = "F_Score")
pval = pd.Series(pval,name="p_value")
cols = pd.Series(cols, name = "Column")
F_reg = pd.concat([cols,fval,pval],axis=1)
F_reg.loc[(F_reg.p_value < 0.05),].sort_values(by = "F_Score",ascending=False)
# Out:
#          Column    F_Score       p_value
# 3  Vehicle_type  12.386085  5.680256e-04
# 1  Manufacturer   3.947240  4.110448e-08

# %% [markdown]
# #### What relationships do you notice?

# %%
#Splitting the data
feature_columns = car_sales_new.columns.difference( ['ln_sales_in_thousands', 'Sales_in_thousands'] )
feature_columns
# Out:
# Index(['Engine_size', 'Fuel_efficiency', 'Horsepower', 'Launch_Year',
#        'Manufacturer_Audi', 'Manufacturer_Dodge', 'Manufacturer_Ford',
#        'Manufacturer_Honda', 'Manufacturer_Jeep', 'Manufacturer_Lexus',
#        'Manufacturer_Mercedes-B', 'Manufacturer_Mitsubishi',
#        'Manufacturer_Nissan', 'Manufacturer_Plymouth', 'Manufacturer_Porsche',
#        'Manufacturer_Toyota', 'Manufacturer_Volvo', 'Power_perf_factor',
#        'Price_in_thousands', 'Vehicle_type_Passenger',
#        'four_year_resale_value'],
#       dtype='object')

# %%
#This will be used in sklearn related functions
from sklearn.cross_validation import train_test_split

train_X, test_X, train_y, test_y = train_test_split( car_sales_new[feature_columns],
                                                  car_sales_new['ln_sales_in_thousands'],
                                                  test_size = 0.3,
                                                  random_state = 1234 )
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print(len( train_X ))
print(len( test_X))
# Out:
# 109
# 48

# %%
from sklearn.cross_validation import train_test_split

train, test = train_test_split( car_sales_new,test_size = 0.3,random_state = 1234 )

# %%
len(train)
# Out:
# 109

# %%
len(test)
# Out:
# 48

# %% [markdown]
# ## Form of linear regression
#
# $y = \beta_0 + \beta_1x_1 + \beta_2x_2 + ... + \beta_nx_n$
#
# - $y$ is the response
# - $\beta_0$ is the intercept
# - $\beta_1$ is the coefficient for $x_1$ (the first feature)
# - $\beta_n$ is the coefficient for $x_n$ (the nth feature)
#
# The $\beta$ values are called the **model coefficients**:
#
# - These values are estimated (or "learned") during the model fitting process using the **least squares criterion**.
# - Specifically, we are find the line (mathematically) which minimizes the **sum of squared residuals** (or "sum of squared errors").
# - And once we've learned these coefficients, we can use the model to predict the response.
#
# ![Estimating coefficients](images/estimating_coefficients.png)
#
# In the diagram above:
#
# - The black dots are the **observed values** of x and y.
# - The blue line is our **least squares line**.
# - The red lines are the **residuals**, which are the vertical distances between the observed values and the least squares line.

# %% [markdown]
# ## Building a linear regression model

# %%
import statsmodels.formula.api as smf

# %%
#m1 = smf.ols('y~x1+x2+x3...xn', data=train) # Definig y & X with classs
#m1 = smf.ols('y~.'' , data = train)
#m1.fit()     #building model (estimating the betas)
#m1.summary() #output
#m1.predict(train)
#m1.predict(test)

# %%
lm=smf.ols('ln_sales_in_thousands~Price_in_thousands+four_year_resale_value+Engine_size+Horsepower+Fuel_efficiency+Vehicle_type_Passenger', train).fit()

# %%
print(lm.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ln_sales_in_thousands   R-squared:                       0.459
# Model:                               OLS   Adj. R-squared:                  0.427
# Method:                    Least Squares   F-statistic:                     14.42
# Date:                   Thu, 11 Jul 2019   Prob (F-statistic):           7.59e-12
# Time:                           11:26:43   Log-Likelihood:                -133.00
# No. Observations:                    109   AIC:                             280.0
# Df Residuals:                        102   BIC:                             298.8
# Df Model:                              6
# Covariance Type:               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.8111      1.387      1.306      0.194      -0.939       4.561
# Price_in_thousands        -0.0874      0.021     -4.177      0.000      -0.129      -0.046
# four_year_resale_value     0.0127      0.017      0.765      0.446      -0.020       0.046
# Engine_size                0.5925      0.205      2.890      0.005       0.186       0.999
# Horsepower                 0.0021      0.005      0.392      0.696      -0.008       0.013
# Fuel_efficiency            0.0849      0.047      1.797      0.075      -0.009       0.179
# Vehicle_type_Passenger    -0.8031      0.289     -2.777      0.007      -1.377      -0.229
# ==============================================================================
# Omnibus:                        4.069   Durbin-Watson:                   2.240
# Prob(Omnibus):                  0.131   Jarque-Bera (JB):                3.817
# Skew:                          -0.458   Prob(JB):                        0.148
# Kurtosis:                       3.010   Cond. No.                     3.35e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
lm=smf.ols('ln_sales_in_thousands~Price_in_thousands+Engine_size+Fuel_efficiency+Vehicle_type_Passenger', train).fit()
print(lm.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ln_sales_in_thousands   R-squared:                       0.455
# Model:                               OLS   Adj. R-squared:                  0.434
# Method:                    Least Squares   F-statistic:                     21.74
# Date:                   Thu, 11 Jul 2019   Prob (F-statistic):           4.69e-13
# Time:                           11:26:43   Log-Likelihood:                -133.35
# No. Observations:                    109   AIC:                             276.7
# Df Residuals:                        104   BIC:                             290.2
# Df Model:                              4
# Covariance Type:               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  1.9202      1.367      1.405      0.163      -0.790       4.630
# Price_in_thousands        -0.0758      0.012     -6.381      0.000      -0.099      -0.052
# Engine_size                0.6453      0.147      4.379      0.000       0.353       0.937
# Fuel_efficiency            0.0846      0.047      1.801      0.075      -0.009       0.178
# Vehicle_type_Passenger    -0.7669      0.279     -2.746      0.007      -1.321      -0.213
# ==============================================================================
# Omnibus:                        4.327   Durbin-Watson:                   2.276
# Prob(Omnibus):                  0.115   Jarque-Bera (JB):                4.129
# Skew:                          -0.477   Prob(JB):                        0.127
# Kurtosis:                       2.980   Cond. No.                         614.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Mathematical equation:
# ln_sales_in_thousands = 1.9043 - 0.0631 * Price_in_thousands + 0.5813* Engine_size + 0.0816*Fuel_efficiency - Vehicle_type_Passenger*0.7356
#
# sales_in_thousands = exp(ln_sales_in_thousands)

# %% [markdown]
# #### Check the multicollinieirity using VIF for all the variables in the model

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices

y, X = dmatrices('ln_sales_in_thousands~Engine_size+Manufacturer_Ford+Manufacturer_Plymouth+Manufacturer_Toyota+four_year_resale_value', train, return_type='dataframe')



# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

vif.round(1)
# Out:
#    VIF Factor                features
# 0        14.6               Intercept
# 1         1.2             Engine_size
# 2         1.0       Manufacturer_Ford
# 3         1.0   Manufacturer_Plymouth
# 4         1.0     Manufacturer_Toyota
# 5         1.3  four_year_resale_value

# %% [markdown]
# #### Predict the Y (Scoring the train & test and validate the results)

# %%
train['pred_sales'] = np.exp(lm.predict(train))-1
train.head()
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 24             17.9470                  36.225              45.705
# 99              1.8708                  14.180              55.835
# 8               9.2310                  28.675              33.400
# 20            135.1260                  11.225              16.535
# 22             42.5930                  11.525              19.390
#
#     Engine_size  Horsepower  Fuel_efficiency  Power_perf_factor  Launch_Year  \
# 24        4.775       300.0             22.0         125.091513         2012
# 99        4.775       300.0             20.0         125.091513         2011
# 8         2.800       193.0             24.0          81.877069         2012
# 20        3.100       170.0             25.0          67.314462         2012
# 22        3.400       180.0             27.0          72.030917         2011
#
#     Manufacturer_Audi  Manufacturer_Dodge  ...  Manufacturer_Mercedes-B  \
# 24                  0                   0  ...                        0
# 99                  0                   0  ...                        1
# 8                   0                   0  ...                        0
# 20                  0                   0  ...                        0
# 22                  0                   0  ...                        0
#
#     Manufacturer_Mitsubishi  Manufacturer_Nissan  Manufacturer_Plymouth  \
# 24                        0                    0                      0
# 99                        0                    0                      0
# 8                         0                    0                      0
# 20                        0                    0                      0
# 22                        0                    0                      0
#
#     Manufacturer_Porsche  Manufacturer_Toyota  Manufacturer_Volvo  \
# 24                     0                    0                   0
# 99                     0                    0                   0
# 8                      0                    0                   0
# 20                     0                    0                   0
# 22                     0                    0                   0
#
#     Vehicle_type_Passenger  ln_sales_in_thousands  pred_sales
# 24                       1               2.887423   12.874064
# 99                       1               0.626366    4.435806
# 8                        1               2.222567   10.675645
# 20                       1               4.906208   54.373081
# 22                       1               3.751690   63.094421
#
# [5 rows x 24 columns]

# %%
test['pred_sales'] = np.exp(lm.predict(test))-1
test.head()
# Out:
# C:\Users\sunitprasad\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# 58            185.3362                  13.210              15.350
# 91             20.3800                  14.795              22.510
# 98             11.5920                  14.180              41.600
# 29             32.7750                  14.180              24.495
# 6               1.8708                  39.000              55.835
#
#     Engine_size  Horsepower  Fuel_efficiency  Power_perf_factor  Launch_Year  \
# 58          2.3       135.0             27.0          54.269548         2012
# 91          3.3       170.0             21.0          69.671461         2009
# 98          3.2       215.0             26.0          92.925792         2011
# 29          2.5       168.0             24.0          69.521355         2011
# 6           4.2       300.0             21.0         125.091513         2012
#
#     Manufacturer_Audi  Manufacturer_Dodge  ...  Manufacturer_Mercedes-B  \
# 58                  0                   0  ...                        0
# 91                  0                   0  ...                        0
# 98                  0                   0  ...                        1
# 29                  0                   0  ...                        0
# 6                   1                   0  ...                        0
#
#     Manufacturer_Mitsubishi  Manufacturer_Nissan  Manufacturer_Plymouth  \
# 58                        0                    0                      0
# 91                        0                    0                      0
# 98                        0                    0                      0
# 29                        0                    0                      0
# 6                         0                    0                      0
#
#     Manufacturer_Porsche  Manufacturer_Toyota  Manufacturer_Volvo  \
# 58                     0                    0                   0
# 91                     0                    0                   0
# 98                     0                    0                   0
# 29                     0                    0                   0
# 6                      0                    0                   0
#
#     Vehicle_type_Passenger  ln_sales_in_thousands  pred_sales
# 58                       1               5.222171   41.811835
# 91                       0               3.014554   60.489296
# 98                       1               2.450315    8.613006
# 29                       1               3.489666   17.896364
# 6                        1               0.626366    3.081774
#
# [5 rows x 24 columns]

# %%
#Accuracy Metrics
#accuracy metrics
MAPE_train = np.mean(np.abs(train['Sales_in_thousands'] - train['pred_sales'])/train['Sales_in_thousands'])
print(MAPE_train)
MAPE_test = np.mean(np.abs(test['Sales_in_thousands'] - test['pred_sales'])/test['Sales_in_thousands'])
print(MAPE_test)
# Out:
# 0.875159037878597
# 1.1890983487517617

# %%
np.corrcoef(train['Sales_in_thousands'],  train['pred_sales'])
# Out:
# array([[1.        , 0.54533129],
#        [0.54533129, 1.        ]])

# %%
corr_train = np.corrcoef(train['Sales_in_thousands'],  train['pred_sales'])[1][[0]]
corr_test = np.corrcoef(test['Sales_in_thousands'],  test['pred_sales'])[1][[0]]
print(corr_train); print(corr_test)
# Out:
# [0.54533129]
# [0.6014886]

# %% [markdown]
# #### Regression with all the variables

# %%
train.columns= [var.strip().replace('-', '') for var in train.columns]
train.columns
# Out:
# Index(['Sales_in_thousands', 'four_year_resale_value', 'Price_in_thousands',
#        'Engine_size', 'Horsepower', 'Fuel_efficiency', 'Power_perf_factor',
#        'Launch_Year', 'Manufacturer_Audi', 'Manufacturer_Dodge',
#        'Manufacturer_Ford', 'Manufacturer_Honda', 'Manufacturer_Jeep',
#        'Manufacturer_Lexus', 'Manufacturer_MercedesB',
#        'Manufacturer_Mitsubishi', 'Manufacturer_Nissan',
#        'Manufacturer_Plymouth', 'Manufacturer_Porsche', 'Manufacturer_Toyota',
#        'Manufacturer_Volvo', 'Vehicle_type_Passenger', 'ln_sales_in_thousands',
#        'pred_sales'],
#       dtype='object')

# %%
all_columns = "+".join(train.columns.difference( ['ln_sales_in_thousands'] ))

print(all_columns)
# Out:
# Engine_size+Fuel_efficiency+Horsepower+Launch_Year+Manufacturer_Audi+Manufacturer_Dodge+Manufacturer_Ford+Manufacturer_Honda+Manufacturer_Jeep+Manufacturer_Lexus+Manufacturer_MercedesB+Manufacturer_Mitsubishi+Manufacturer_Nissan+Manufacturer_Plymouth+Manufacturer_Porsche+Manufacturer_Toyota+Manufacturer_Volvo+Power_perf_factor+Price_in_thousands+Sales_in_thousands+Vehicle_type_Passenger+four_year_resale_value+pred_sales

# %%
my_formula = "ln_sales_in_thousands~" + all_columns

print(my_formula)
# Out:
# ln_sales_in_thousands~Engine_size+Fuel_efficiency+Horsepower+Launch_Year+Manufacturer_Audi+Manufacturer_Dodge+Manufacturer_Ford+Manufacturer_Honda+Manufacturer_Jeep+Manufacturer_Lexus+Manufacturer_MercedesB+Manufacturer_Mitsubishi+Manufacturer_Nissan+Manufacturer_Plymouth+Manufacturer_Porsche+Manufacturer_Toyota+Manufacturer_Volvo+Power_perf_factor+Price_in_thousands+Sales_in_thousands+Vehicle_type_Passenger+four_year_resale_value+pred_sales

# %%
model2 = smf.ols(my_formula, data=train).fit()
print(model2.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ln_sales_in_thousands   R-squared:                       0.868
# Model:                               OLS   Adj. R-squared:                  0.833
# Method:                    Least Squares   F-statistic:                     24.39
# Date:                   Thu, 11 Jul 2019   Prob (F-statistic):           3.39e-28
# Time:                           11:26:50   Log-Likelihood:                -55.932
# No. Observations:                    109   AIC:                             159.9
# Df Residuals:                         85   BIC:                             224.5
# Df Model:                             23
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                -124.2018    173.200     -0.717      0.475    -468.570     220.166
# Engine_size                 0.3638      0.197      1.845      0.068      -0.028       0.756
# Fuel_efficiency             0.0955      0.036      2.663      0.009       0.024       0.167
# Horsepower                 -0.0120      0.009     -1.267      0.209      -0.031       0.007
# Launch_Year                 0.0623      0.086      0.724      0.471      -0.109       0.234
# Manufacturer_Audi           0.3910      0.352      1.110      0.270      -0.309       1.091
# Manufacturer_Dodge         -0.3341      0.226     -1.477      0.143      -0.784       0.116
# Manufacturer_Ford          -0.6053      0.256     -2.367      0.020      -1.114      -0.097
# Manufacturer_Honda         -0.7071      0.490     -1.444      0.152      -1.681       0.267
# Manufacturer_Jeep          -0.0781      0.326     -0.239      0.811      -0.727       0.570
# Manufacturer_Lexus         -0.0192      0.257     -0.075      0.941      -0.530       0.492
# Manufacturer_MercedesB     -0.0881      0.302     -0.292      0.771      -0.689       0.512
# Manufacturer_Mitsubishi    -0.2536      0.218     -1.163      0.248      -0.687       0.180
# Manufacturer_Nissan         0.2064      0.232      0.889      0.376      -0.255       0.668
# Manufacturer_Plymouth      -0.8395      0.286     -2.934      0.004      -1.408      -0.271
# Manufacturer_Porsche        0.2351      0.546      0.431      0.668      -0.850       1.320
# Manufacturer_Toyota        -0.2046      0.218     -0.938      0.351      -0.638       0.229
# Manufacturer_Volvo          0.0547      0.243      0.225      0.822      -0.428       0.537
# Power_perf_factor           0.0511      0.028      1.842      0.069      -0.004       0.106
# Price_in_thousands         -0.1005      0.023     -4.347      0.000      -0.146      -0.055
# Sales_in_thousands          0.0179      0.001     12.237      0.000       0.015       0.021
# Vehicle_type_Passenger     -0.9590      0.243     -3.947      0.000      -1.442      -0.476
# four_year_resale_value      0.0124      0.011      1.134      0.260      -0.009       0.034
# pred_sales                 -0.0150      0.007     -2.267      0.026      -0.028      -0.002
# ==============================================================================
# Omnibus:                       23.511   Durbin-Watson:                   2.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.529
# Skew:                          -1.046   Prob(JB):                     5.24e-08
# Kurtosis:                       4.734   Cond. No.                     7.99e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.99e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Feature Selection based on importance using F-Regression

# %%
# Feature Selection based on importance
from sklearn.feature_selection import f_regression
features = train_X
target = train_y
F_values, p_values  = f_regression(features, target )

# %%
import itertools
f_reg_results = [(i, v, z) for i, v, z in itertools.zip_longest(features.columns, F_values,  ['%.3f' % p for p in p_values])]

f_reg_results=pd.DataFrame(f_reg_results, columns=['Variable','F_Value', 'P_Value'])

# %%
f_reg_results.sort_values(by=['P_Value'])

f_reg_results.P_Value = pd.to_numeric(f_reg_results.P_Value)

# %%
f_reg_results_new=f_reg_results[f_reg_results.P_Value<=0.2]

f_reg_results_new

# %% [markdown]
# If p - values are less, then variables are siginificant in the regression equation.

# %% [markdown]
# #### Model building

# %%
#Create formula after selection of variables from f-regression

# %%
my_formula = 'ln_sales_in_thousands~Engine_size+Manufacturer_Ford+Manufacturer_Plymouth+Manufacturer_Toyota+Price_in_thousands'

# %%
lm = smf.ols(my_formula, data=train).fit()
print(lm.summary())

# %%
lm.predict(train)

# %%
train['pred_ln_sales'] = lm.predict(train)

# %%
train.head()

# %%
test['pred_ln_sales']  = lm.predict(test)

# %%
test.head()

# %%
train['actual_sales'] = np.exp(train.ln_sales_in_thousands)
test['actual_sales'] = np.exp(test.ln_sales_in_thousands)

train['pred_sales'] = np.exp(train.pred_ln_sales)
test['pred_sales'] = np.exp(test.pred_ln_sales)

# %%
train.head()

# %%
test.head()

# %%
# calculate these metrics by hand!
from sklearn import metrics
import numpy as np
import scipy.stats as stats

# %%
#Train Data
MAPE_train = np.mean(np.abs(train.actual_sales - train.pred_sales)/train.actual_sales )
print(MAPE_train)


RMSE_train = metrics.mean_squared_error(train.actual_sales , train.pred_sales)
print(RMSE_train)

Corr_train = stats.stats.pearsonr(train.actual_sales , train.pred_sales)
print(Corr_train)


#Test Data
MAPE_test = np.mean(np.abs(test.actual_sales - test.pred_sales)/test.actual_sales )
print(MAPE_test)

RMSE_test = metrics.mean_squared_error(test.actual_sales , test.pred_sales)
print(RMSE_test)

Corr_test = stats.stats.pearsonr(test.actual_sales , test.pred_sales)
print(Corr_test)

# %%
#Possible reasons for model is not validating (over fitting)

#Data preparation problem (outliers, missings, variable conversions etc. not correct)
#not included right variables
#If the data have multicollinerity
#Including more number of variables 
#Data size is very low  (ideally we should have 1varaible = 100 obs)
#The assumptions are not 100% valid
#The variables are not explaining completely

# how to over come this problem
#Increase the data size
# Change the variables - Reiterate the model with different combinations of variables
# Apply right transformations on X variables such the the linear relationship between Y & X will imrpvove
#Add dervied variables which can explain Y better
#Re look into data preparation steps
#Look at the Importance of variables include them in the model
#Change the technique

# %%
# THere are few techniques can help you to identify important variables (Variable selection - Feature selection)
# F-Regression
# RFE - Recursive feature elimination - Stepwise regression

# %%
#Residuals Diagnostics

# %%
lm.resid.hist(bins=100)

# %%
sns.distplot(lm.resid)

# %%
stats.pearsonr(train.ln_sales_in_thousands, lm.resid)

# %% [markdown]
# ### Exercise: Decile Analysis for Linear Regression

# %%
train.columns

# %%
### Decile Analysis
#Decile analysis for validation of models - Business validation

train['Deciles']=pd.qcut(train['pred_sales'],10, labels=False)
test['Deciles']=pd.qcut(test['pred_sales'],10, labels=False)

# %%
# Decile Analysis for train data
Predicted_avg = train[['Deciles','pred_sales']].groupby(train.Deciles).mean().sort_index(ascending=False)['pred_sales']
Actual_avg = train[['Deciles','Sales_in_thousands']].groupby(train.Deciles).mean().sort_index(ascending=False)['Sales_in_thousands']

Decile_analysis_train = pd.concat([Predicted_avg, Actual_avg], axis=1)

Decile_analysis_train

# %%
# Decile Analysis for train data
Predicted_avg = test[['Deciles','pred_sales']].groupby(test.Deciles).mean().sort_index(ascending=False)['pred_sales']
Actual_avg = test[['Deciles','Sales_in_thousands']].groupby(test.Deciles).mean().sort_index(ascending=False)['Sales_in_thousands']

# %%
Decile_analysis_test = pd.concat([Predicted_avg, Actual_avg], axis=1)

Decile_analysis_test

# %%
Decile_analysis_train.to_csv('Decile_analysis_train.csv')

Decile_analysis_test.to_csv('Decile_analysis_test.csv')

# %%
#Key Checks: Compare the deciles for training & testing as follows
    #Rank orderng
    #Decile wise comparision between actual & predicted

# %% [markdown]
# ### USING sklearn Library to build the model
# > sklearn library has a comprehensive set of APIs to split datasets, build models, test models and calculate accuracy metrics

# %%
## Building the model with train set and make predictions on test set
from sklearn.linear_model import LinearRegression
from sklearn import metrics

linreg = LinearRegression()
linreg.fit( train_X, train_y )

# %%
linreg.coef_

# %%
linreg.score(train_X, train_y)

# %%
y_pred_t = linreg.predict(train_X)
y_pred_t

# %%
y_pred_t = linreg.predict(train_X)
rmse_t = np.sqrt( metrics.mean_squared_error( train_y, y_pred_t) )
print(rmse_t)
print(metrics.r2_score( train_y, y_pred_t ))

# %%
y_pred = linreg.predict( test_X )
rmse = np.sqrt( metrics.mean_squared_error( test_y, y_pred ) )
print(rmse)
print(metrics.r2_score( test_y, y_pred ))

# %%
residuals = train_y - y_pred_t

# %%
sns.jointplot(  train_y, residuals )

# %%
sns.distplot( residuals )

# %%
# To ensure residues are random i.e. normally distributed a Q-Q plot can be used
# Q-Q plot shows if the residuals are plotted along the line.
from scipy import stats
import pylab

stats.probplot( residuals, dist="norm", plot=pylab )
pylab.show()

# %% [markdown]
# The residuals are randomly distributed. There are no visible relationship. The model can be assumed to be correct

# %%
### K-FOLD CROSS VALIDATION
from sklearn.cross_validation import cross_val_score

# %%
linreg = LinearRegression()

# %%
cross_val_score( linreg, train_X, train_y, scoring = 'r2', cv = 10 )

# %%
round( np.mean( cross_val_score( linreg,
                              train_X,
                              train_y,
                              scoring = 'r2',
                              cv = 10 ) ), 2 )

# %% [markdown]
# ### Other Reading information

# %% [markdown]
# ### Feature selection
#
# How do we choose which features to include in the model? We're going to use **train/test split** (and eventually **cross-validation**).
#
# Why not use of **p-values** or **R-squared** for feature selection?
#
# - Linear models rely upon **a lot of assumptions** (such as the features being independent), and if those assumptions are violated, p-values and R-squared are less reliable. Train/test split relies on fewer assumptions.
# - Features that are unrelated to the response can still have **significant p-values**.
# - Adding features to your model that are unrelated to the response will always **increase the R-squared value**, and adjusted R-squared does not sufficiently account for this.
# - p-values and R-squared are **proxies** for our goal of generalization, whereas train/test split and cross-validation attempt to **directly estimate** how well the model will generalize to out-of-sample data.
#
# More generally:
#
# - There are different methodologies that can be used for solving any given data science problem, and this course follows a **machine learning methodology**.
# - This course focuses on **general purpose approaches** that can be applied to any model, rather than model-specific approaches.

# %% [markdown]
# ### Evaluating Model Accuracy
# > R-squared is a statistical measure of how close the data are to the fitted regression line. <br>
# > R-square signifies percentage of variations in the reponse variable that can be explained by the model. <br>
# > - R-squared = Explained variation / Total variation <br>
# > - Total variation is variation of response variable around it's mean. <br>
#
# > R-squared value varies between 0 and 100%. 0% signifies that the model explains none of the variability, <br>
# while 100% signifies that the model explains all the variability of the response. <br>
# The closer the r-square to 100%, the better is the model. <br>

# %% [markdown]
# ## Other Evaluation metrics for regression problems
#
# Evaluation metrics for classification problems, such as **accuracy**, are not useful for regression problems. We need evaluation metrics designed for comparing **continuous values**.
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %% [markdown]
# ## Comparing linear regression with other models
#
# Advantages of linear regression:
#
# - Simple to explain
# - Highly interpretable
# - Model training and prediction are fast
# - No tuning is required (excluding regularization)
# - Features don't need scaling
# - Can perform well with a small number of observations
# - Well-understood
#
# Disadvantages of linear regression:
#
# - Presumes a linear relationship between the features and the response
# - Performance is (generally) not competitive with the best supervised learning methods due to high bias
# - Can't automatically learn feature interactions
